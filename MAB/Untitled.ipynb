# %%
from bandits import Bandit, multi_armed_bandit, show_result

# %%
import pickle
with open('./dataset/EU_data.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
with open('./dataset/USStockData.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
result, df0 = multi_armed_bandit(data, epsilon=0.1,step_size=0.1, sample_averages=True, UCB_param=None, gradient=False, gradient_baseline=False)    
show_result(df0,result)

# %%
result, df0 = multi_armed_bandit(data, epsilon=0.1,step_size=0.1, sample_averages=True, UCB_param=None, gradient=False, gradient_baseline=False, America=True)    
show_result(df0,result)
